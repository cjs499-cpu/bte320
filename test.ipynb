# %% [markdown]
# <a href="https://colab.research.google.com/github/cjs499-cpu/bte320/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for loop in range (1,5):
  print ('Hey')
# Out:
# Hey
# Hey
# Hey
# Hey
